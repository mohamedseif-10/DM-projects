# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error
from sklearn.ensemble import RandomForestRegressor

# %%
data = pd.read_csv('../Data/processed_data.csv')
data
# Out:
#            Price    Mileage  Brand  Model  Automatic Transmission  \
# 0      14.845130   5.707110     59    738                    True
# 1      13.997833  11.782960     32    789                    True
# 2      14.533351  11.736077     47    805                    True
# 3      14.533351  11.338584      5    842                    True
# 4      13.458837  11.225257     18    618                    True
# ...          ...        ...    ...    ...                     ...
# 21975  13.235694  11.751950     17    158                    True
# 21976  13.664689   8.853808     76    743                    True
# 21977  13.815512  12.429220      9    812                    True
# 21978  15.110238   9.305741      5     65                    True
# 21979  14.133965  11.813037     73    192                    True
#
#        Air Conditioner  Power Steering  Remote Control  Years_of_usage
# 0                 True            True            True               0
# 1                 True            True            True               3
# 2                 True            True            True               3
# 3                 True            True            True               6
# 4                 True            True            True               3
# ...                ...             ...             ...             ...
# 21975             True            True            True               4
# 21976             True            True            True               0
# 21977             True            True            True              11
# 21978             True            True            True               1
# 21979             True            True            True              15
#
# [21980 rows x 9 columns]

# %%
X = data.drop(columns='Price')
y = data['Price']
y
# Out:
# 0        14.845130
# 1        13.997833
# 2        14.533351
# 3        14.533351
# 4        13.458837
#            ...
# 21975    13.235694
# 21976    13.664689
# 21977    13.815512
# 21978    15.110238
# 21979    14.133965
# Name: Price, Length: 21980, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
model = RandomForestRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)

# %%
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'R-squared: {r2:.2f}')
# Out:
# Root Mean Squared Error (RMSE): 0.30
# Mean Absolute Error (MAE): 0.21
# R-squared: 0.88

# %%
result = pd.DataFrame({'Y_k' : np.expm1(y_test) / 1000 ,
                       'Y_pred_k' : np.expm1(y_pred) / 1000})
result.head(20)
# Out:
#           Y_k     Y_pred_k
# 10534  6800.0  4960.329209
# 11227   250.0   464.984920
# 14319  1270.0  1621.647686
# 17615   820.0   675.278405
# 16922  2000.0  1042.860582
# 14855   460.0   351.060725
# 3643   4200.0  4093.192154
# 1595   1450.0  1162.755651
# 18046   450.0   406.875563
# 12528   850.0  1028.165802
# 7606   1000.0   930.367997
# 8274    870.0   810.836692
# 17271   415.0   151.781520
# 6418    675.0   696.791961
# 7658    980.0   825.232797
# 18008  1000.0   950.648985
# 2638    370.0   328.874206
# 13874  4250.0  4370.067248
# 3894   2700.0  2361.660912
# 6492    360.0   298.474380

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, s=100, label='Predictions')
sns.lineplot(x=[min(y_test), max(y_test)], y=[min(y_test), max(y_test)], color='red',  label='Ideal Prediction')
plt.xlabel('True Values (Y)')
plt.ylabel('Predicted Values (Y_pred)')
plt.title('True vs Predicted Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# * # Add new values

# %%
n_Brand = input("Enter a car Brand")
n_Model = input("Enter a car Model")
n_year_of_make = int(input("Enter a car made year"))
n_Mileage = int(input("Enter How many KMs this car was driven"))
is_automatic = input("Is it Automatic Transmission? Y/N").lower()
is_air = input("Is it Air Conditioner? Y/N").lower()
is_power = input("Is it Power Steering? Y/N").lower()
is_remote = input("Is it Remote Control? Y/N").lower()

# %%
input_data = pd.DataFrame(
    {
        'Brand' : [n_Brand],
        'Model' : [n_Model],
        'n_year_of_make' : [n_year_of_make],
        'Mileage' : [n_Mileage],
        'Automatic Transmission' : [is_automatic],
        'Air Conditioner' : [is_air],
        'Power Steering' : [is_power],
        'Remote Control' : [is_remote]
    }
)

input_data
# Out:
#   Brand Model  n_year_of_make  Mileage Automatic Transmission Air Conditioner  \
# 0   BMW    X3            2020    20000                      y               y
#
#   Power Steering Remote Control
# 0              y              y

# %%
for col in ["Automatic Transmission", "Air Conditioner", "Power Steering", "Remote Control"]:
    input_data[col].replace({'y' : True, 'n' : False}, inplace=True)
input_data
# Out:
# /tmp/ipykernel_4456/3054165006.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   input_data[col].replace({'y' : True, 'n' : False}, inplace=True)
# /tmp/ipykernel_4456/3054165006.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   input_data[col].replace({'y' : True, 'n' : False}, inplace=True)
#   Brand Model  n_year_of_make  Mileage  Automatic Transmission  \
# 0   BMW    X3            2020    20000                    True
#
#    Air Conditioner  Power Steering  Remote Control
# 0             True            True            True

# %%
input_data["Mileage"] = np.log1p(input_data["Mileage"])
input_data
# Out:
#   Brand Model  n_year_of_make   Mileage  Automatic Transmission  \
# 0   BMW    X3            2020  9.903538                    True
#
#    Air Conditioner  Power Steering  Remote Control
# 0             True            True            True

# %%
input_data["Years_of_usage"] = 2024 - input_data["n_year_of_make"]
input_data.drop(columns="n_year_of_make", axis=1, inplace=True)
input_data
# Out:
#   Brand Model   Mileage  Automatic Transmission  Air Conditioner  \
# 0   BMW    X3  9.903538                    True             True
#
#    Power Steering  Remote Control  Years_of_usage
# 0            True            True               4

# %%
input_data[input_data["Years_of_usage"] < 0].replace({-1 : 0})
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Mileage, Automatic Transmission, Air Conditioner, Power Steering, Remote Control, Years_of_usage]
# Index: []

# %%
input_data
# Out:
#   Brand Model   Mileage  Automatic Transmission  Air Conditioner  \
# 0   BMW    X3  9.903538                    True             True
#
#    Power Steering  Remote Control  Years_of_usage
# 0            True            True               4

# %%
import joblib
loaded_label_encoder_Brand = joblib.load("../Preprocessing/label_encoder_Make.pkl")
loaded_label_encoder_Model = joblib.load("../Preprocessing/label_encoder_Model.pkl")

# %%
try:
    input_data["Brand"] = loaded_label_encoder_Brand.transform(input_data["Brand"])
    input_data["Model"] = loaded_label_encoder_Model.transform(input_data["Model"])
except:
    input_data["Brand"] = np.nan
    input_data["Model"] = np.nan

# %%
input_data
# Out:
#    Brand  Model   Mileage  Automatic Transmission  Air Conditioner  \
# 0      5    845  9.903538                    True             True
#
#    Power Steering  Remote Control  Years_of_usage
# 0            True            True               4

# %%
input_data.dtypes
# Out:
# Brand                       int64
# Model                       int64
# Mileage                   float64
# Automatic Transmission       bool
# Air Conditioner              bool
# Power Steering               bool
# Remote Control               bool
# Years_of_usage              int64
# dtype: object

# %%
input_data = input_data[["Mileage", "Brand", "Model", 'Automatic Transmission','Air Conditioner','Power Steering','Remote Control','Years_of_usage']]
input_data
# Out:
#     Mileage  Brand  Model  Automatic Transmission  Air Conditioner  \
# 0  9.903538      5    845                    True             True
#
#    Power Steering  Remote Control  Years_of_usage
# 0            True            True               4

# %%
n_y = model.predict(input_data)
print(f"The price of this car will be {round(np.expm1(n_y[0]))} EGP.")
# Out:
# The price of this car will be 3255058 EGP.
